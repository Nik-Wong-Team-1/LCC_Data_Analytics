# %% [markdown]
# # Importing Tools and Data

# %%
import seaborn as sns
# %matplotlib inline 
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\niwong\OneDrive - Healthfirst\Desktop\NYPD_Arrest_Data__Year_to_Date__20240501.csv")

# %% [markdown]
# # Understanding the Data

# %%
df.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0   280255493  01/10/2024  397.0  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 1   279805419  01/02/2024  157.0                          RAPE 1  104.0
# 2   279895750  01/03/2024  101.0                       ASSAULT 3  344.0
# 3   280809090  01/19/2024  511.0  CONTROLLED SUBSTANCE, POSSESSI  235.0
# 4   280357135  01/11/2024  109.0        ASSAULT 2,1,UNCLASSIFIED  106.0
#
#                       OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                       ROBBERY  PL 1601001          F           M
# 1                          RAPE  PL 1303501          F           K
# 2  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           Q
# 3               DANGEROUS DRUGS  PL 2200300          M           B
# 4                FELONY ASSAULT  PL 1200502          F           K
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX       PERP_RACE  \
# ...

# %%
df.dtypes
# Out:
# ARREST_KEY                    int64
# ARREST_DATE                  object
# PD_CD                       float64
# PD_DESC                      object
# KY_CD                       float64
# OFNS_DESC                    object
# LAW_CODE                     object
# LAW_CAT_CD                   object
# ARREST_BORO                  object
# ARREST_PRECINCT               int64
# JURISDICTION_CODE             int64
# AGE_GROUP                    object
# PERP_SEX                     object
# PERP_RACE                    object
# X_COORD_CD                    int64
# Y_COORD_CD                    int64
# Latitude                    float64
# Longitude                   float64
# New Georeferenced Column     object
# dtype: object

# %%
df. count()
# Out:
# ARREST_KEY                  63621
# ARREST_DATE                 63621
# PD_CD                       63619
# PD_DESC                     63621
# KY_CD                       63612
# OFNS_DESC                   63621
# LAW_CODE                    63621
# LAW_CAT_CD                  63219
# ARREST_BORO                 63621
# ARREST_PRECINCT             63621
# JURISDICTION_CODE           63621
# AGE_GROUP                   63621
# PERP_SEX                    63621
# PERP_RACE                   63621
# X_COORD_CD                  63621
# Y_COORD_CD                  63621
# Latitude                    63621
# Longitude                   63621
# New Georeferenced Column    63621
# dtype: int64

# %%
df.groupby (by= "PERP_SEX"). count()
# Out:
#           ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  LAW_CODE  \
# PERP_SEX
# F              11189        11189  11189    11189  11186      11189     11189
# M              52432        52432  52430    52432  52426      52432     52432
#
#           LAW_CAT_CD  ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE  \
# PERP_SEX
# F              11145        11189            11189              11189
# M              52074        52432            52432              52432
#
#           AGE_GROUP  PERP_RACE  X_COORD_CD  Y_COORD_CD  Latitude  Longitude  \
# PERP_SEX
# F             11189      11189       11189       11189     11189      11189
# M             52432      52432       52432       52432     52432      52432
#
#           New Georeferenced Column
# PERP_SEX
# F                            11189
# M                            52432

# %%
df.groupby (by= "ARREST_BORO"). count()
# Out:
#              ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  \
# ARREST_BORO
# B                 14221        14221  14221    14221  14219      14221
# K                 17402        17402  17401    17402  17397      17402
# M                 15324        15324  15323    15324  15322      15324
# Q                 13782        13782  13782    13782  13782      13782
# S                  2892         2892   2892     2892   2892       2892
#
#              LAW_CODE  LAW_CAT_CD  ARREST_PRECINCT  JURISDICTION_CODE  \
# ARREST_BORO
# B               14221       14125            14221              14221
# K               17402       17338            17402              17402
# M               15324       15152            15324              15324
# Q               13782       13727            13782              13782
# S                2892        2877             2892               2892
#
#              AGE_GROUP  PERP_SEX  PERP_RACE  X_COORD_CD  Y_COORD_CD  Latitude  \
# ...

# %%
df.groupby (by= "PERP_RACE"). count()
# Out:
#                                 ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  \
# PERP_RACE
# AMERICAN INDIAN/ALASKAN NATIVE         185          185    185      185
# ASIAN / PACIFIC ISLANDER              3543         3543   3543     3543
# BLACK                                29466        29466  29464    29466
# BLACK HISPANIC                        6336         6336   6336     6336
# UNKNOWN                                293          293    293      293
# WHITE                                 6607         6607   6607     6607
# WHITE HISPANIC                       17191        17191  17191    17191
#
#                                 KY_CD  OFNS_DESC  LAW_CODE  LAW_CAT_CD  \
# PERP_RACE
# AMERICAN INDIAN/ALASKAN NATIVE    185        185       185         184
# ASIAN / PACIFIC ISLANDER         3542       3543      3543        3507
# BLACK                           29462      29466     29466       29322
# BLACK HISPANIC                   6336       6336      6336        6274
# ...

# %%
df.groupby (by= "AGE_GROUP"). count()
# Out:
#            ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  \
# AGE_GROUP
# 18-24           10684        10684  10684    10684  10684      10684
# 25-44           37254        37254  37252    37254  37250      37254
# 45-64           12315        12315  12315    12315  12312      12315
# 65+              1041         1041   1041     1041   1041       1041
# <18              2327         2327   2327     2327   2325       2327
#
#            LAW_CODE  LAW_CAT_CD  ARREST_BORO  ARREST_PRECINCT  \
# AGE_GROUP
# 18-24         10684       10631        10684            10684
# 25-44         37254       36977        37254            37254
# 45-64         12315       12248        12315            12315
# 65+            1041        1036         1041             1041
# <18            2327        2327         2327             2327
#
#            JURISDICTION_CODE  PERP_SEX  PERP_RACE  X_COORD_CD  Y_COORD_CD  \
# AGE_GROUP
# ...

# %%
df.groupby (by= "ARREST_DATE"). count()
# Out:
#              ARREST_KEY  PD_CD  PD_DESC  KY_CD  OFNS_DESC  LAW_CODE  \
# ARREST_DATE
# 01/01/2024          466    466      466    466        466       466
# 01/02/2024          643    643      643    643        643       643
# 01/03/2024          826    826      826    826        826       826
# 01/04/2024          872    872      872    872        872       872
# 01/05/2024          670    670      670    670        670       670
# ...                 ...    ...      ...    ...        ...       ...
# 03/27/2024          890    890      890    890        890       890
# 03/28/2024          610    610      610    610        610       610
# 03/29/2024          633    633      633    633        633       633
# 03/30/2024          464    464      464    464        464       464
# 03/31/2024          366    366      366    366        366       366
#
#              LAW_CAT_CD  ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE  \
# ARREST_DATE
# ...

# %%
df.groupby (by= "LAW_CAT_CD"). count()
# Out:
#             ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  \
# LAW_CAT_CD
# (null)               2            2      0        2      0          2
# 9                  155          155    155      155    155        155
# F                26653        26653  26653    26653  26650      26653
# I                   54           54     54       54     54         54
# M                35580        35580  35580    35580  35576      35580
# V                  775          775    775      775    775        775
#
#             LAW_CODE  ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE  \
# LAW_CAT_CD
# (null)             2            2                2                  2
# 9                155          155              155                155
# F              26653        26653            26653              26653
# I                 54           54               54                 54
# M              35580        35580            35580              35580
# ...

# %% [markdown]
# # Data Cleaning: Removing Columns That Will Not be Relevant and Values Not Found in the Data Dictionary, Like LAW_CAT_CD's "9"

# %%
drop_cols = ["PD_CD", "KY_CD", "LAW_CAT_CD", "JURISDICTION_CODE", "X_COORD_CD", "Y_COORD_CD", "Latitude", "Longitude", "New Georeferenced Column"]
df.drop (drop_cols, inplace = True, axis=1)

# %% [markdown]
# # Filtering Out the Bronx (Primary Entity to Analyze)

# %%
df2= df[(df["ARREST_BORO"] == "B")]
df2.head(20)
# Out:
#     ARREST_KEY ARREST_DATE                           PD_DESC  \
# 3    280809090  01/19/2024    CONTROLLED SUBSTANCE, POSSESSI
# 9    281426006  01/31/2024                            RAPE 2
# 16   282248602  02/15/2024                         ASSAULT 3
# 22   283166738  03/04/2024                            RAPE 3
# 31   281488926  02/01/2024    LARCENY,PETIT FROM OPEN AREAS,
# 35   281297202  01/29/2024    LARCENY,PETIT FROM OPEN AREAS,
# 39   280805057  01/19/2024             MENACING,UNCLASSIFIED
# 42   279786329  01/01/2024    TRAFFIC,UNCLASSIFIED MISDEMEAN
# 45   280206714  01/09/2024    CONTROLLED SUBSTANCE, POSSESSI
# 48   280989216  01/23/2024  CRIMINAL MISCHIEF,UNCLASSIFIED 4
# 49   280255470  01/10/2024               OBSTR BREATH/CIRCUL
# 50   280672588  01/17/2024    THEFT OF SERVICES, UNCLASSIFIE
# 53   281366460  01/30/2024    TRAFFIC,UNCLASSIFIED INFRACTIO
# 54   279947725  01/04/2024          ASSAULT 2,1,UNCLASSIFIED
# ...

# %%
df2.count()
# Out:
# ARREST_KEY         14221
# ARREST_DATE        14221
# PD_DESC            14221
# OFNS_DESC          14221
# LAW_CODE           14221
# ARREST_BORO        14221
# ARREST_PRECINCT    14221
# AGE_GROUP          14221
# PERP_SEX           14221
# PERP_RACE          14221
# dtype: int64

# %%
df2.groupby (by= "AGE_GROUP"). count()
# Out:
#            ARREST_KEY  ARREST_DATE  PD_DESC  OFNS_DESC  LAW_CODE  ARREST_BORO  \
# AGE_GROUP
# 18-24            2629         2629     2629       2629      2629         2629
# 25-44            8416         8416     8416       8416      8416         8416
# 45-64            2477         2477     2477       2477      2477         2477
# 65+               184          184      184        184       184          184
# <18               515          515      515        515       515          515
#
#            ARREST_PRECINCT  PERP_SEX  PERP_RACE
# AGE_GROUP
# 18-24                 2629      2629       2629
# 25-44                 8416      8416       8416
# 45-64                 2477      2477       2477
# 65+                    184       184        184
# <18                    515       515        515

# %% [markdown]
# # Filtering Out Staten Island, Brooklyn, Manhattan, and Queens

# %%
df3= df[(df["ARREST_BORO"] == "S")]
df3.head(3)
# Out:
#     ARREST_KEY ARREST_DATE                         PD_DESC  \
# 30   280912825  01/22/2024  TRAFFIC,UNCLASSIFIED MISDEMEAN
# 61   279795390  01/02/2024  PUBLIC ADMINISTATION,UNCLASS M
# 81   280511912  01/14/2024  TRAFFIC,UNCLASSIFIED MISDEMEAN
#
#                          OFNS_DESC    LAW_CODE ARREST_BORO  ARREST_PRECINCT  \
# 30        VEHICLE AND TRAFFIC LAWS  VTL05110A4           S              120
# 61  OFFENSES AGAINST PUBLIC ADMINI  PL 1950500           S              121
# 81        VEHICLE AND TRAFFIC LAWS  VTL05110MU           S              120
#
#    AGE_GROUP PERP_SEX PERP_RACE
# 30     18-24        M     WHITE
# 61     25-44        M     WHITE
# 81     25-44        M     WHITE

# %%
df4= df[(df["ARREST_BORO"] == "K")]
df4.head(3)
# Out:
#     ARREST_KEY ARREST_DATE                   PD_DESC       OFNS_DESC  \
# 1    279805419  01/02/2024                    RAPE 1            RAPE
# 4    280357135  01/11/2024  ASSAULT 2,1,UNCLASSIFIED  FELONY ASSAULT
# 11   281422833  01/31/2024         STRANGULATION 1ST  FELONY ASSAULT
#
#       LAW_CODE ARREST_BORO  ARREST_PRECINCT AGE_GROUP PERP_SEX       PERP_RACE
# 1   PL 1303501           K               77     25-44        M  WHITE HISPANIC
# 4   PL 1200502           K               81     25-44        F           BLACK
# 11  PL 1211200           K               81     25-44        M           BLACK

# %%
df5= df[(df["ARREST_BORO"] == "M")]
df5.head(3)
# Out:
#    ARREST_KEY ARREST_DATE                         PD_DESC  \
# 0   280255493  01/10/2024  ROBBERY,OPEN AREA UNCLASSIFIED
# 6   280769124  01/19/2024                        JOSTLING
# 7   281338081  01/30/2024                       ASSAULT 3
#
#                       OFNS_DESC    LAW_CODE ARREST_BORO  ARREST_PRECINCT  \
# 0                       ROBBERY  PL 1601001           M               26
# 6                      JOSTLING  PL 1652501           M                6
# 7  ASSAULT 3 & RELATED OFFENSES  PL 1200001           M               26
#
#   AGE_GROUP PERP_SEX PERP_RACE
# 0       <18        M     BLACK
# 6     25-44        M     BLACK
# 7     25-44        M     BLACK

# %%
df6= df[(df["ARREST_BORO"] == "Q")]
df6.head(3)
# Out:
#     ARREST_KEY ARREST_DATE            PD_DESC                     OFNS_DESC  \
# 2    279895750  01/03/2024          ASSAULT 3  ASSAULT 3 & RELATED OFFENSES
# 5    281488967  02/01/2024             RAPE 1                          RAPE
# 10   281606761  02/03/2024  STRANGULATION 1ST                FELONY ASSAULT
#
#       LAW_CODE ARREST_BORO  ARREST_PRECINCT AGE_GROUP PERP_SEX  \
# 2   PL 1200001           Q              106       65+        F
# 5   PL 1303501           Q              113     25-44        M
# 10  PL 1211200           Q              102     45-64        M
#
#                    PERP_RACE
# 2                      WHITE
# 5                      BLACK
# 10  ASIAN / PACIFIC ISLANDER

# %% [markdown]
# # Data Visualizations for Trend Analysis

# %%
df2.groupby (["AGE_GROUP"]). count(). plot(kind= "bar", xlabel= "Age of Arestee", ylabel="Count", title= "Arrests by Age in the Bronx", color="Red", legend=False)
df3.groupby (["AGE_GROUP"]). count(). plot(kind= "bar", xlabel= "Age of Arestee", ylabel="Count", title= "Arrests by Age in Staten Island", color="Blue", legend=False)
df4.groupby (["AGE_GROUP"]). count(). plot(kind= "bar", xlabel= "Age of Arestee", ylabel="Count", title= "Arrests by Age in Brooklyn", color="Blue", legend=False)
df5.groupby (["AGE_GROUP"]). count(). plot(kind= "bar", xlabel= "Age of Arestee", ylabel="Count", title= "Arrests by Age in Manhattan", color="Blue", legend=False)
df6.groupby (["AGE_GROUP"]). count(). plot(kind= "bar", xlabel= "Age of Arestee", ylabel="Count", title= "Arrests by Age in Queens", color="Blue", legend=False)
# Out:
# <Axes: title={'center': 'Arrests by Age in Queens'}, xlabel='Age of Arestee', ylabel='Count'>

# %% [markdown]
# # Additional Analysis of the Bronx (Age 18-24)

# %%
df7= df2[(df2["AGE_GROUP"] == "18-24")]
df7.head()
# Out:
#     ARREST_KEY ARREST_DATE                         PD_DESC  \
# 9    281426006  01/31/2024                          RAPE 2
# 16   282248602  02/15/2024                       ASSAULT 3
# 22   283166738  03/04/2024                          RAPE 3
# 74   280921631  01/22/2024  TRAFFIC,UNCLASSIFIED INFRACTIO
# 76   280228021  01/09/2024           MENACING,UNCLASSIFIED
#
#                        OFNS_DESC    LAW_CODE ARREST_BORO  ARREST_PRECINCT  \
# 9                           RAPE  PL 1303001           B               41
# 16  ASSAULT 3 & RELATED OFFENSES  PL 1200001           B               47
# 22                          RAPE  PL 1302503           B               45
# 74      OTHER TRAFFIC INFRACTION  VTL051101A           B               43
# 76  ASSAULT 3 & RELATED OFFENSES  PL 1201401           B               46
#
#    AGE_GROUP PERP_SEX       PERP_RACE
# 9      18-24        M           BLACK
# 16     18-24        M           BLACK
# 22     18-24        M  WHITE HISPANIC
# ...

# %%
df7.groupby (by= "OFNS_DESC"). count()
# Out:
#                                   ARREST_KEY  ARREST_DATE  PD_DESC  LAW_CODE  \
# OFNS_DESC
# ALCOHOLIC BEVERAGE CONTROL LAW             1            1        1         1
# ASSAULT 3 & RELATED OFFENSES             385          385      385       385
# BURGLAR'S TOOLS                            2            2        2         2
# BURGLARY                                  42           42       42        42
# CANNABIS RELATED OFFENSES                 16           16       16        16
# CHILD ABANDONMENT/NON SUPPORT              1            1        1         1
# CRIMINAL MISCHIEF & RELATED OF            94           94       94        94
# CRIMINAL TRESPASS                         24           24       24        24
# DANGEROUS DRUGS                           88           88       88        88
# DANGEROUS WEAPONS                        184          184      184       184
# DISORDERLY CONDUCT                         1            1        1         1
# ...

# %%
df7.groupby (["OFNS_DESC"]). count(). plot(kind= "bar", xlabel= "Arrest Description", ylabel="Count", title= "Arrests Descriptions in the Bronx (18-24 Years of Age)", color="Red", legend=False)
# Out:
# <Axes: title={'center': 'Arrests Descriptions in the Bronx (18-24 Years of Age)'}, xlabel='Arrest Description', ylabel='Count'>

# %% [markdown]
# # Analysis

# %% [raw]
# Based on the data analysis above, the Bronx's distribution of arrests by age is similar to other boroughs. Age group 25-44 have the highest number of arrestees in each borough. However, the Bronx is the only borough that has more reported arrestees between the ages of 18-24 than 45-64. This could suggest that there may be factors that increase the likelihood of this age group participating in criminal acts within the Bronx. Based on an additional analysis, the top three types of crime within the age group in the Bronx are Assault 3 & Related Offenses, Felony Assault, and Vehicle and Traffic Laws.
#
# This analysis mitigates bias because it does not exclude any reported arrests within the window of time that the data was collected (Q1 2024). Additionally, we mitigate bias further by just comparing the distribution trends of arrests by age within each borough. Since all the boroughs have a different number of arrests, this analysis does not compare specific numerical values by borough.
