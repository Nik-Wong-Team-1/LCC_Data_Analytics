# %% [markdown]
# # Importing Tools and Data

# %%
import seaborn as sns
# %matplotlib inline 
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/niteen11/DataAnalyticsAcademy/master/Python/dataset_diabetes/diabetic_data.csv')

# %% [markdown]
# # Getting to Know the Data

# %%
df
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# ...

# %%
df.groupby (by= 'gender'). count()
# Out:
#                  encounter_id  patient_nbr   race    age  weight  \
# gender
# Female                  54708        54708  54708  54708   54708
# Male                    47055        47055  47055  47055   47055
# Unknown/Invalid             3            3      3      3       3
#
#                  admission_type_id  discharge_disposition_id  \
# gender
# Female                       54708                     54708
# Male                         47055                     47055
# Unknown/Invalid                  3                         3
#
#                  admission_source_id  time_in_hospital  payer_code  ...  \
# gender                                                              ...
# Female                         54708             54708       54708  ...
# Male                           47055             47055       47055  ...
# Unknown/Invalid                    3                 3           3  ...
#
#                  citoglipton  insulin  glyburide-metformin  \
# gender
# ...

# %%
df.groupby (by= 'diabetesMed'). count()
# Out:
#              encounter_id  patient_nbr   race  gender    age  weight  \
# diabetesMed
# No                  23403        23403  23403   23403  23403   23403
# Yes                 78363        78363  78363   78363  78363   78363
#
#              admission_type_id  discharge_disposition_id  admission_source_id  \
# diabetesMed
# No                       23403                     23403                23403
# Yes                      78363                     78363                78363
#
#              time_in_hospital  ...  examide  citoglipton  insulin  \
# diabetesMed                    ...
# No                      23403  ...    23403        23403    23403
# Yes                     78363  ...    78363        78363    78363
#
#              glyburide-metformin  glipizide-metformin  \
# diabetesMed
# No                         23403                23403
# Yes                        78363                78363
#
#              glimepiride-pioglitazone  metformin-rosiglitazone  \
# ...

# %% [markdown]
# # Data Cleaning

# %%
drop_cols = ['weight', 'readmitted']
df.drop (drop_cols, inplace = True, axis=1)

# %%
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age  \
# 0       2278392      8222157        Caucasian  Female   [0-10)
# 1        149190     55629189        Caucasian  Female  [10-20)
# 2         64410     86047875  AfricanAmerican  Female  [20-30)
# 3        500364     82442376        Caucasian    Male  [30-40)
# 4         16680     42519267        Caucasian    Male  [40-50)
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital payer_code  ... examide  citoglipton  insulin  \
# 0                 1          ?  ...      No           No       No
# ...

# %%
df1 = df[df['gender'] != 'Unknown/Invalid']

# %%
df1.groupby (by= 'gender'). count()
# Out:
#         encounter_id  patient_nbr   race    age  admission_type_id  \
# gender
# Female         54708        54708  54708  54708              54708
# Male           47055        47055  47055  47055              47055
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# gender
# Female                     54708                54708             54708
# Male                       47055                47055             47055
#
#         payer_code  medical_specialty  ...  examide  citoglipton  insulin  \
# gender                                 ...
# Female       54708              54708  ...    54708        54708    54708
# Male         47055              47055  ...    47055        47055    47055
#
#         glyburide-metformin  glipizide-metformin  glimepiride-pioglitazone  \
# gender
# Female                54708                54708                     54708
# Male                  47055                47055                     47055
#
# ...

# %% [markdown]
# # Filtering Desired Data Based on Gender and Reported Diabetes Medication Use

# %%
df2= df1[['gender','diabetesMed']]
df2.head()
# Out:
#    gender diabetesMed
# 0  Female          No
# 1  Female         Yes
# 2  Female         Yes
# 3    Male         Yes
# 4    Male         Yes

# %%
df3= df2[(df2['gender'] == 'Female')]
df3
# Out:
#         gender diabetesMed
# 0       Female          No
# 1       Female         Yes
# 2       Female         Yes
# 8       Female         Yes
# 9       Female         Yes
# ...        ...         ...
# 101757  Female         Yes
# 101758  Female         Yes
# 101760  Female         Yes
# 101762  Female         Yes
# 101764  Female         Yes
#
# [54708 rows x 2 columns]

# %%
df3.groupby (by= 'diabetesMed'). count()
# Out:
#              gender
# diabetesMed
# No            12921
# Yes           41787

# %%
df4= df2[(df2['gender'] == 'Male')]
df4
# Out:
#        gender diabetesMed
# 3        Male         Yes
# 4        Male         Yes
# 5        Male         Yes
# 6        Male         Yes
# 7        Male         Yes
# ...       ...         ...
# 101753   Male         Yes
# 101759   Male         Yes
# 101761   Male         Yes
# 101763   Male         Yes
# 101765   Male          No
#
# [47055 rows x 2 columns]

# %%
df4.groupby (by= 'diabetesMed'). count()
# Out:
#              gender
# diabetesMed
# No            10481
# Yes           36574

# %% [markdown]
# # Data Visualization and Compairing Data Trends

# %%
df3.groupby (['diabetesMed']). count(). plot(kind='bar', xlabel='Responses', ylabel='Count', title= 'Females and Diabetes Medication Prescribed', color='pink', legend=False)
df4.groupby (['diabetesMed']). count(). plot(kind='bar', xlabel='Responses', ylabel='Count', title= 'Males and Diabetes Medication Prescribed', color='blue', legend=False)
# Out:
# <Axes: title={'center': 'Males and Diabetes Medication Prescribed'}, xlabel='Responses', ylabel='Count'>

# %% [markdown]
# # Key Observations
# Diabetes medication prescription trends suggest that diabetes management is highly relevant for both genders. From a marketing perspective, this suggests that we should target both men and women with diabetes management content.

# %% [markdown]
# # Additional Analysis...

# %% [markdown]
# # Filtering Data Based on Gender, Age, and Diabetes Medication Use

# %%
df5= df[['gender', 'age', 'diabetesMed']]
df5.head()
# Out:
#    gender      age diabetesMed
# 0  Female   [0-10)          No
# 1  Female  [10-20)         Yes
# 2  Female  [20-30)         Yes
# 3    Male  [30-40)         Yes
# 4    Male  [40-50)         Yes

# %%
df6= df5[(df5['gender'] == 'Female')]
df6
# Out:
#         gender       age diabetesMed
# 0       Female    [0-10)          No
# 1       Female   [10-20)         Yes
# 2       Female   [20-30)         Yes
# 8       Female   [80-90)         Yes
# 9       Female  [90-100)         Yes
# ...        ...       ...         ...
# 101757  Female   [70-80)         Yes
# 101758  Female   [80-90)         Yes
# 101760  Female   [60-70)         Yes
# 101762  Female   [80-90)         Yes
# 101764  Female   [80-90)         Yes
#
# [54708 rows x 3 columns]

# %%
df7= df6[(df6['diabetesMed'] != 'No')]
df7.head(10)
# Out:
#     gender       age diabetesMed
# 1   Female   [10-20)         Yes
# 2   Female   [20-30)         Yes
# 8   Female   [80-90)         Yes
# 9   Female  [90-100)         Yes
# 10  Female   [40-50)         Yes
# 12  Female   [40-50)         Yes
# 14  Female   [60-70)         Yes
# 17  Female   [50-60)         Yes
# 20  Female   [50-60)         Yes
# 24  Female   [70-80)         Yes

# %%
df7.groupby (by= 'age'). count()
# Out:
#           gender  diabetesMed
# age
# [0-10)        71           71
# [10-20)      350          350
# [20-30)      863          863
# [30-40)     1585         1585
# [40-50)     3606         3606
# [50-60)     6665         6665
# [60-70)     8642         8642
# [70-80)    10775        10775
# [80-90)     7868         7868
# [90-100)    1362         1362

# %%
df8= df5[(df5['gender'] == 'Male')]
df8
# Out:
#        gender      age diabetesMed
# 3        Male  [30-40)         Yes
# 4        Male  [40-50)         Yes
# 5        Male  [50-60)         Yes
# 6        Male  [60-70)         Yes
# 7        Male  [70-80)         Yes
# ...       ...      ...         ...
# 101753   Male  [40-50)         Yes
# 101759   Male  [80-90)         Yes
# 101761   Male  [70-80)         Yes
# 101763   Male  [70-80)         Yes
# 101765   Male  [70-80)          No
#
# [47055 rows x 3 columns]

# %%
df9= df8[(df8['diabetesMed'] != 'No')]
df9.head(10)
# Out:
#    gender      age diabetesMed
# 3    Male  [30-40)         Yes
# 4    Male  [40-50)         Yes
# 5    Male  [50-60)         Yes
# 6    Male  [60-70)         Yes
# 7    Male  [70-80)         Yes
# 11   Male  [60-70)         Yes
# 13   Male  [80-90)         Yes
# 15   Male  [60-70)         Yes
# 16   Male  [50-60)         Yes
# 18   Male  [70-80)         Yes

# %%
df9.groupby (by= 'age'). count()
# Out:
#           gender  diabetesMed
# age
# [0-10)        62           62
# [10-20)      250          250
# [20-30)      452          452
# [30-40)     1264         1264
# [40-50)     3799         3799
# [50-60)     6736         6736
# [60-70)     8969         8969
# [70-80)     9414         9414
# [80-90)     5046         5046
# [90-100)     582          582

# %% [markdown]
# # Data Visualization and Compairing Data Trends

# %%
df7.groupby (['age']). count(). plot(kind='bar', xlabel='Age', ylabel='Count', title= 'Females Prescribed Diabetes Medication (By Age)', color='pink', legend=False)
df9.groupby (['age']). count(). plot(kind='bar', xlabel='Age', ylabel='Count', title= 'Males Prescribed Diabetes Medication (By Age)', color='blue', legend=False)
# Out:
# <Axes: title={'center': 'Males Prescribed Diabetes Medication (By Age)'}, xlabel='Age', ylabel='Count'>

# %% [markdown]
# # Additional Key Observations
# Further analysis shows that female and male audiences who are between 70-80 years of age report the highest number of diabetes medication perscriptions. This suggests that diabetes management is the most relevant for audiences between 70-80 years old. From a marketing perspective, this indicates that we should prioritize sharing diabetes management content with men and women who are 70-80 years old either through their caregivers or their senior living facilities.
